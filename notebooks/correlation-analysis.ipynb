# %%
import pandas as pd
import numpy as np
import wfdb
import ast
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '../data/physionet.org/files/ptb-xl/1.0.2/'
sampling_rate=100

# %% [markdown]
# # Load data

# %%
def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

# %%
# load and convert annotation data
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))


# Load scp_statements.csv for diagnostic aggregation
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.diagnostic == 1]

def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

def aggregate_diagnostic_subclass(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_subclass)
    return list(set(tmp))

# Apply diagnostic superclass
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)
Y['diagnostic_subclass'] = Y.scp_codes.apply(aggregate_diagnostic_subclass)


Y
# Out:
#         patient_id    age  sex  height  weight  nurse  site      device
# ecg_id
# 1          15709.0   56.0    1     NaN    63.0    2.0   0.0   CS-12   E  \
# 2          13243.0   19.0    0     NaN    70.0    2.0   0.0   CS-12   E
# 3          20372.0   37.0    1     NaN    69.0    2.0   0.0   CS-12   E
# 4          17014.0   24.0    0     NaN    82.0    2.0   0.0   CS-12   E
# 5          17448.0   19.0    1     NaN    70.0    2.0   0.0   CS-12   E
# ...            ...    ...  ...     ...     ...    ...   ...         ...
# 21833      17180.0   67.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21834      20703.0  300.0    0     NaN     NaN    1.0   2.0  AT-60    3
# 21835      19311.0   59.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21836       8873.0   64.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21837      11744.0   68.0    0     NaN     NaN    1.0   2.0  AT-60    3
#
#              recording_date
# ecg_id
# 1       1984-11-09 09:17:34  \
# ...

# %%
# Load raw signal data
X = load_raw_data(Y, sampling_rate, path)

# %%
X.shape
# Out:
# (21801, 1000, 12)

# %%
ecg_data = X[1]



fig, ax = plt.subplots(figsize=(13, 9))


# Create a line plot for each feature
for i, feature in enumerate(range(ecg_data.shape[1])):
    plt.plot(ecg_data[:, feature] , label=f'Feature {feature + 1}')

# %%
X.shape
# Out:
# (21801, 1000, 12)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sample_data = ecg_data.copy()

# Convert the sample data to a DataFrame for easier computation
df = pd.DataFrame(sample_data, columns=[f'Feature {i+1}' for i in range(12)])

# Compute the correlation matrix
correlation_matrix = df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=.5)
plt.title('Correlation Matrix for Sample ' + str(sample_idx))
plt.show()

# %% [markdown]
# Nice! Single example shows that this could be a good way to go. Let's try it on a few more examples.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

X_data = X.copy()  # shape (21801, 1000, 12)

# Randomly select 1024 samples
num_samples = 1024
selected_samples = np.random.choice(X_data.shape[0], num_samples, replace=False)
sampled_data = X_data[selected_samples]

# Compute and accumulate the correlation matrix for each sample
cumulative_corr_matrix = np.zeros((12, 12))
for sample in tqdm(sampled_data, total=len(sampled_data)):
    df = pd.DataFrame(sample, columns=[f'Feature {i+1}' for i in range(12)])
    cumulative_corr_matrix += df.corr().values

# Average the correlation matrices
average_corr_matrix = cumulative_corr_matrix / num_samples

# Visualize the average correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(average_corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=.5)
plt.show()
# Out:
# 100%|██████████| 1024/1024 [00:00<00:00, 3875.29it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load history.csv
df = pd.read_csv("history.csv")

# columns are epoch	train_loss	valid_loss	multi_label_accuracy	multilabel_hamming_loss	macro_f1_score_multilabel

# %%
df
# Out:
#     epoch  train_loss  valid_loss  multi_label_accuracy
# 0       0    0.476213    0.433826              0.803298  \
# 1       1    0.426279    0.393457              0.828472
# 2       2    0.406352    0.394863              0.832513
# 3       3    0.389138    0.373394              0.843381
# 4       4    0.379535    0.377345              0.845796
# 5       5    0.376319    0.371703              0.842220
# 6       6    0.365128    0.364107              0.848258
# 7       7    0.362657    0.368013              0.846679
# 8       8    0.356794    0.366278              0.847701
# 9       9    0.355582    0.368002              0.848955
# 10     10    0.349593    0.367944              0.849745
# 11     11    0.344498    0.362482              0.851974
# 12     12    0.343509    0.360883              0.849884
# 13     13    0.339721    0.357364              0.851510
# 14     14    0.337573    0.360436              0.851510
# 15     15    0.335769    0.363274              0.851045
# 16     16    0.336356    0.346145              0.853506
# 17     17    0.322089    0.369662              0.850581
# 18     18    0.329904    0.354057              0.854296
# 19     19    0.323878    0.359102              0.851509
# 20     20    0.322668    0.354582              0.852485
# 21     21    0.320020    0.350958              0.855783
# 22     22    0.314920    0.355239              0.854668
# 23     23    0.318329    0.347541              0.854622
# 24     24    0.311733    0.354634              0.853181
# 25     25    0.311114    0.354189              0.852438
# 26     26    0.307440    0.352429              0.853692
# 27     27    0.305718    0.360670              0.849512
# 28     28    0.302385    0.352869              0.855040
# 29     29    0.296988    0.357483              0.852856
# 30     30    0.300730    0.356898              0.853042
# 31     31    0.295538    0.354372              0.854854
# 32     32    0.294171    0.353484              0.853925
# 33     33    0.287398    0.353124              0.854853
# 34     34    0.289065    0.354537              0.852021
# 35     35    0.286736    0.351483              0.856433
# 36     36    0.282100    0.350287              0.856758
# 37     37    0.280460    0.352423              0.855876
# 38     38    0.276281    0.352799              0.856201
# 39     39    0.281275    0.354843              0.855411
# 40     40    0.278426    0.350816              0.856154
# 41     41    0.275953    0.353114              0.854482
# 42     42    0.277855    0.347786              0.855922
# 43     43    0.277509    0.350760              0.854204
# 44     44    0.278575    0.351644              0.855411
# 45     45    0.274432    0.349025              0.856944
# 46     46    0.271569    0.349168              0.856433
# 47     47    0.274472    0.350665              0.856990
#
#     multilabel_hamming_loss  macro_f1_score_multilabel   time
# 0                  0.196702                   0.432847  01:01
# 1                  0.171528                   0.499230  01:00
# 2                  0.167487                   0.512297  01:00
# 3                  0.156619                   0.526557  01:00
# 4                  0.154203                   0.555260  01:00
# 5                  0.157780                   0.560186  01:00
# 6                  0.151742                   0.569462  01:00
# 7                  0.153321                   0.573867  01:00
# 8                  0.152299                   0.564281  01:00
# 9                  0.151045                   0.556629  01:00
# 10                 0.150255                   0.567123  01:00
# 11                 0.148026                   0.576773  01:00
# 12                 0.150116                   0.571036  01:00
# 13                 0.148490                   0.587450  01:00
# 14                 0.148490                   0.582563  01:00
# 15                 0.148955                   0.575038  01:00
# 16                 0.146493                   0.587188  01:00
# 17                 0.149419                   0.586556  01:00
# 18                 0.145704                   0.598139  01:00
# 19                 0.148490                   0.589896  01:00
# 20                 0.147515                   0.588383  01:00
# 21                 0.144217                   0.591849  01:00
# 22                 0.145332                   0.597995  01:00
# 23                 0.145379                   0.591908  01:00
# 24                 0.146818                   0.593464  01:00
# 25                 0.147562                   0.590599  01:00
# 26                 0.146307                   0.594400  01:00
# 27                 0.150488                   0.585395  01:00
# 28                 0.144961                   0.602535  01:00
# 29                 0.147144                   0.593856  01:00
# 30                 0.146958                   0.592819  01:00
# 31                 0.145146                   0.604898  01:00
# 32                 0.146075                   0.599487  01:00
# 33                 0.145146                   0.611704  01:00
# 34                 0.147980                   0.606530  01:00
# 35                 0.143567                   0.611099  01:00
# 36                 0.143242                   0.612835  01:00
# 37                 0.144124                   0.611478  01:00
# 38                 0.143799                   0.616833  01:00
# 39                 0.144589                   0.613591  01:00
# 40                 0.143846                   0.617621  01:00
# 41                 0.145518                   0.613317  01:00
# 42                 0.144078                   0.615483  01:00
# 43                 0.145797                   0.610271  01:00
# 44                 0.144589                   0.614640  01:00
# 45                 0.143056                   0.617109  01:00
# 46                 0.143567                   0.620491  01:00
# 47                 0.143010                   0.617786  01:00

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.train_loss, label='train_loss')
plt.plot(df.epoch, df.valid_loss, label='valid_loss')

plt.legend()
# plt.xlim(0, 5)
# plt.ylim(0.1, 0.3)

# %%
import numpy as np

# print row with the best validation loss
row_indx = np.argmin(df["valid_loss"])
df.iloc[row_indx]
# Out:
# epoch                              16
# train_loss                   0.336356
# valid_loss                   0.346145
# multi_label_accuracy         0.853506
# multilabel_hamming_loss      0.146493
# macro_f1_score_multilabel    0.587188
# time                            01:00
# Name: 16, dtype: object

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.multi_label_accuracy, label='multi_label_accuracy')

plt.legend()

# %%
plt.plot(df.epoch, df.multilabel_hamming_loss, label='multilabel_hamming_loss')

plt.legend()

# %%
plt.plot(df.epoch, df.macro_f1_score_multilabel, label='macro_f1_score_multilabel')

plt.legend()

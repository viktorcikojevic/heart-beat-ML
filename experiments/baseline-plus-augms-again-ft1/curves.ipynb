# %%
import pandas as pd
import matplotlib.pyplot as plt

# load history.csv
df = pd.read_csv("history.csv")

# columns are epoch	train_loss	valid_loss	multi_label_accuracy	multilabel_hamming_loss	macro_f1_score_multilabel

# %%
df
# Out:
#    epoch  train_loss  valid_loss  multi_label_accuracy
# 0      0    0.250145    0.223132              0.913269  \
# 1      1    0.247601    0.221782              0.911895
# 2      2    0.245522    0.222423              0.915025
# 3      3    0.242023    0.223602              0.910673
# 4      4    0.229992    0.223104              0.912200
# 5      5    0.224757    0.223711              0.912887
# 6      6    0.217940    0.222774              0.913575
# 7      7    0.210570    0.220207              0.911513
# 8      8    0.205898    0.225726              0.909834
# 9      9    0.205138    0.222735              0.911437
#
#    multilabel_hamming_loss  macro_f1_score_multilabel   time
# 0                 0.086731                   0.638372  01:08
# 1                 0.088105                   0.653814  01:06
# 2                 0.084975                   0.652212  01:07
# 3                 0.089327                   0.639462  01:07
# 4                 0.087800                   0.641048  01:07
# 5                 0.087113                   0.654421  01:06
# 6                 0.086425                   0.649955  01:07
# 7                 0.088487                   0.641824  01:07
# 8                 0.090166                   0.632424  01:07
# 9                 0.088563                   0.642018  01:07

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.train_loss, label='train_loss')
plt.plot(df.epoch, df.valid_loss, label='valid_loss')

plt.legend()
# plt.xlim(0, 5)
# plt.ylim(0.1, 0.3)

# %%
import numpy as np

# print row with the best validation loss
row_indx = np.argmin(df["valid_loss"])
df.iloc[row_indx]
# Out:
# epoch                               7
# train_loss                    0.21057
# valid_loss                   0.220207
# multi_label_accuracy         0.911513
# multilabel_hamming_loss      0.088487
# macro_f1_score_multilabel    0.641824
# time                            01:07
# Name: 7, dtype: object

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.multi_label_accuracy, label='multi_label_accuracy')

plt.legend()

# %%
plt.plot(df.epoch, df.multilabel_hamming_loss, label='multilabel_hamming_loss')

plt.legend()

# %%
plt.plot(df.epoch, df.macro_f1_score_multilabel, label='macro_f1_score_multilabel')

plt.legend()

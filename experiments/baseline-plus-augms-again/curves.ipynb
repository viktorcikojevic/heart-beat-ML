# %%
import pandas as pd
import matplotlib.pyplot as plt

# load history.csv
df = pd.read_csv("history.csv")

# columns are epoch	train_loss	valid_loss	multi_label_accuracy	multilabel_hamming_loss	macro_f1_score_multilabel

# %%
df
# Out:
#     epoch  train_loss  valid_loss  multi_label_accuracy
# 0       0    0.296108    0.275634              0.881127  \
# 1       1    0.270668    0.248683              0.898000
# 2       2    0.260345    0.245156              0.897084
# 3       3    0.256260    0.241095              0.902428
# 4       4    0.250385    0.234634              0.903344
# 5       5    0.245978    0.236960              0.900443
# 6       6    0.246614    0.230934              0.902657
# 7       7    0.238946    0.226459              0.907467
# 8       8    0.238036    0.230263              0.903802
# 9       9    0.238171    0.230553              0.905711
# 10     10    0.234823    0.231837              0.905329
# 11     11    0.229532    0.226160              0.907620
# 12     12    0.234860    0.221767              0.910368
# 13     13    0.226501    0.222651              0.911208
# 14     14    0.219579    0.223046              0.910750
# 15     15    0.219044    0.221219              0.907314
# 16     16    0.218352    0.223131              0.910062
# 17     17    0.212671    0.219881              0.911742
# 18     18    0.208483    0.219635              0.911590
# 19     19    0.207363    0.221551              0.910902
# 20     20    0.205378    0.223066              0.910597
# 21     21    0.203946    0.219647              0.910063
# 22     22    0.200251    0.221963              0.910674
# 23     23    0.202052    0.222201              0.913345
# 24     24    0.198027    0.222950              0.910597
# 25     25    0.195251    0.222677              0.913498
# 26     26    0.196061    0.222969              0.911513
# 27     27    0.192106    0.225829              0.909910
# 28     28    0.192597    0.225708              0.914033
# 29     29    0.188666    0.223300              0.913727
# 30     30    0.194016    0.227191              0.912124
# 31     31    0.189773    0.228233              0.911360
#
#     multilabel_hamming_loss  macro_f1_score_multilabel   time
# 0                  0.118873                   0.423784  01:08
# 1                  0.102000                   0.553672  01:06
# 2                  0.102916                   0.563143  01:06
# 3                  0.097572                   0.575676  01:06
# 4                  0.096656                   0.597455  01:06
# 5                  0.099557                   0.591209  01:06
# 6                  0.097343                   0.577999  01:06
# 7                  0.092533                   0.605240  01:06
# 8                  0.096198                   0.609498  01:06
# 9                  0.094289                   0.625187  01:06
# 10                 0.094671                   0.619732  01:06
# 11                 0.092381                   0.624508  01:06
# 12                 0.089632                   0.638611  01:06
# 13                 0.088792                   0.637071  01:06
# 14                 0.089250                   0.647278  01:06
# 15                 0.092686                   0.629252  01:07
# 16                 0.089937                   0.629653  01:06
# 17                 0.088258                   0.652933  01:06
# 18                 0.088410                   0.641377  01:06
# 19                 0.089098                   0.644918  01:06
# 20                 0.089403                   0.646705  01:07
# 21                 0.089937                   0.640313  01:07
# 22                 0.089327                   0.633429  01:06
# 23                 0.086654                   0.651899  01:07
# 24                 0.089403                   0.635976  01:07
# 25                 0.086502                   0.648393  01:07
# 26                 0.088487                   0.635610  01:06
# 27                 0.090090                   0.645881  01:07
# 28                 0.085967                   0.662488  01:06
# 29                 0.086273                   0.655016  01:07
# 30                 0.087876                   0.655541  01:07
# 31                 0.088639                   0.646998  01:07

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.train_loss, label='train_loss')
plt.plot(df.epoch, df.valid_loss, label='valid_loss')

plt.legend()
# plt.xlim(0, 5)
# plt.ylim(0.1, 0.3)

# %%
import numpy as np

# print row with the best validation loss
row_indx = np.argmin(df["valid_loss"])
df.iloc[row_indx]
# Out:
# epoch                              18
# train_loss                   0.208483
# valid_loss                   0.219635
# multi_label_accuracy          0.91159
# multilabel_hamming_loss       0.08841
# macro_f1_score_multilabel    0.641377
# time                            01:06
# Name: 18, dtype: object

# %%
# plot train and valid loss vs epoch
plt.plot(df.epoch, df.multi_label_accuracy, label='multi_label_accuracy')

plt.legend()

# %%
plt.plot(df.epoch, df.multilabel_hamming_loss, label='multilabel_hamming_loss')

plt.legend()

# %%
plt.plot(df.epoch, df.macro_f1_score_multilabel, label='macro_f1_score_multilabel')

plt.legend()
